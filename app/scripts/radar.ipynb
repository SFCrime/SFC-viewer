# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("radar_raw.csv")

# %%
def toCSV(df):
    df.to_csv("radar.csv")

# %%
df.date.value_counts()
# Out:
# 2014-10-26    27
# 2014-10-21    25
# 2014-10-25    25
# 2014-10-24    25
# 2014-10-29    25
# 2014-10-28    25
# 2014-10-22    20
# dtype: int64

# %%
df.category.value_counts()
# Out:
# BURGLARY                       7
# VANDALISM                      7
# WEAPON LAWS                    7
# SECONDARY CODES                7
# WARRANTS                       7
# DRUG/NARCOTIC                  7
# LARCENY/THEFT                  7
# ROBBERY                        7
# OTHER OFFENSES                 7
# SUSPICIOUS OCC                 7
# FRAUD                          7
# VEHICLE THEFT                  7
# STOLEN PROPERTY                7
# MISSING PERSON                 7
# ASSAULT                        7
# NON-CRIMINAL                   7
# FORGERY/COUNTERFEITING         6
# DRUNKENNESS                    6
# KIDNAPPING                     5
# SEX OFFENSES- FORCIBLE         5
# DRIVING UNDER THE INFLUENCE    5
# TRESPASS                       5
# ARSON                          4
# EMBEZZLEMENT                   4
# DISORDERLY CONDUCT             3
# FAMILY OFFENSES                3
# RUNAWAY                        3
# LOITERING                      2
# ...

# %%
ndf = df[df.category.isin(['BURGLARY','VANDALISM','WEAPON LAWS','DRUG/NARCOTIC', 'LARCENY/THEFT', "ROBBERY", "VEHICLE THEFT", "ASSAULT", "ARSON"])]

# %%
ndf = df[df.category.isin(['BURGLARY','VANDALISM','WEAPON LAWS','DRUG/NARCOTIC', 'LARCENY/THEFT', "ROBBERY", "VEHICLE THEFT", "ASSAULT", "ARSON"])].pivot_table(index='date',columns='category',values='count')

# %%
ndf.T/pd.DataFrame(ndf.max()).T
# Out:
#                2014-10-21  2014-10-22  2014-10-24  2014-10-25  2014-10-26  \
# 0                     NaN         NaN         NaN         NaN         NaN
# ARSON                 NaN         NaN         NaN         NaN         NaN
# ASSAULT               NaN         NaN         NaN         NaN         NaN
# BURGLARY              NaN         NaN         NaN         NaN         NaN
# DRUG/NARCOTIC         NaN         NaN         NaN         NaN         NaN
# LARCENY/THEFT         NaN         NaN         NaN         NaN         NaN
# ROBBERY               NaN         NaN         NaN         NaN         NaN
# VANDALISM             NaN         NaN         NaN         NaN         NaN
# VEHICLE THEFT         NaN         NaN         NaN         NaN         NaN
# WEAPON LAWS           NaN         NaN         NaN         NaN         NaN
#
#                2014-10-28  2014-10-29  ARSON  ASSAULT  BURGLARY  \
# 0                     NaN         NaN    NaN      NaN       NaN
# ...

# %%
ndf.astype(np.float64)/ndf.loc[ndf.abs().idxmax()].astype(np.float64)
# Out:
# category    ARSON  ASSAULT  BURGLARY  DRUG/NARCOTIC  LARCENY/THEFT  ROBBERY  \
# date
# 2014-10-21    NaN        1         1              1              1        1
# 2014-10-22    NaN      NaN       NaN            NaN            NaN      NaN
# 2014-10-24    NaN        1         1              1              1        1
# 2014-10-25      1        1         1              1              1        1
# 2014-10-25      1        1         1              1              1        1
# 2014-10-26      1        1         1              1              1        1
# 2014-10-28    NaN      NaN       NaN            NaN            NaN      NaN
# 2014-10-29    NaN        1         1              1              1        1
# 2014-10-29    NaN        1         1              1              1        1
# 2014-10-29    NaN        1         1              1              1        1
# 2014-10-29    NaN        1         1              1              1        1
#
# category    VANDALISM  VEHICLE THEFT  WEAPON LAWS
# ...

# %%
toCSV(.fillna(0))
